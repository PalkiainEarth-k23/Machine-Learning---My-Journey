# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("C:/Users/srini/Downloads/spam.csv")
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df['Spam'] = df['Category'].apply(lambda x: 1 if x=='spam' else 0)
df.head()
# Out:
#   Category                                            Message  Spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %%
X_train , X_test, Y_train, Y_test = train_test_split(df.Message, df.Spam , test_size = 0.2)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
SM = Pipeline([
    ('V', CountVectorizer()),
    ('M' , MultinomialNB())
])

# %%
SM.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 SM.fit(X_train, Y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\pipeline.py:654, in Pipeline.fit(self, X, y, **params)
#     647 if not _routing_enabled() and self.transform_input is not None:
#     648     raise ValueError(
#     649         "The `transform_input` parameter can only be set if metadata "
#     650         "routing is enabled. You can enable metadata routing using "
#     651         "`sklearn.set_config(enable_metadata_routing=True)`."
#     652     )
# --> 654 routed_params = self._check_method_params(method="fit", props=params)
#     655 Xt = self._fit(X, y, routed_params, raw_params=params)
#     656 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File ~\anaconda3\Lib\site-packages\sklearn\pipeline.py:454, in Pipeline._check_method_params(self, method, props, **kwargs)
#     449     return routed_params
#     450 else:
#     451     fit_params_steps = Bunch(
#     452         **{
#     453             name: Bunch(**{method: {} for method in METHODS})
# --> 454             for name, step in self.steps
#     455             if step is not None
#     456         }
#     457     )
#     458     for pname, pval in props.items():
#     459         if "__" not in pname:
#
# ValueError: not enough values to unpack (expected 2, got 1)
