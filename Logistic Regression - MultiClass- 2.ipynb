# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib
from matplotlib import pyplot as plt

# %%
flower = load_iris()
plt.scatter(flower.data[:, 0], flower.data[:, 1], c=flower.target)
plt.xlabel(flower.feature_names[0])
plt.ylabel(flower.feature_names[1])
plt.show()

# %%
X = flower.data
Y = flower.target
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2)
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
Y_predict = model.predict(X_test)
Y_predict
# Out:
# array([2, 2, 1, 0, 2, 0, 2, 0, 0, 0, 1, 0, 1, 2, 2, 1, 0, 0, 1, 1, 0, 2,
#        0, 1, 1, 0, 2, 1, 0, 2])

# %%
model.score(X_test, Y_test)
# Out:
# 0.9666666666666667

# %%
from sklearn.metrics import confusion_matrix
Error_matrix = confusion_matrix(Y_predict, Y_test)
Error_matrix
# Out:
# array([[3, 6, 3],
#        [3, 3, 3],
#        [3, 1, 5]])
