# %%
import pandas as pd
import sklearn.linear_model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/srini/Downloads/HR_comma_sep.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
Required_df = df[['satisfaction_level', 'average_montly_hours', 'promotion_last_5years', 'salary', 'left']]
Required_df.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary  \
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low
#
#    left
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
Dummy = pd.get_dummies(df.salary, prefix="salary")
Dummy.head()
# Out:
#    salary_high  salary_low  salary_medium
# 0        False        True          False
# 1        False       False           True
# 2        False       False           True
# 3        False        True          False
# 4        False        True          False

# %%
merged = pd.concat([Required_df, Dummy], axis = 'columns')
merged.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary  \
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low
#
#    left  salary_high  salary_low  salary_medium
# 0     1        False        True          False
# 1     1        False       False           True
# 2     1        False       False           True
# 3     1        False        True          False
# 4     1        False        True          False

# %%
final = merged.drop(['salary'], axis= 'columns')
final.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  left  \
# 0                0.38                   157                      0     1
# 1                0.80                   262                      0     1
# 2                0.11                   272                      0     1
# 3                0.72                   223                      0     1
# 4                0.37                   159                      0     1
#
#    salary_high  salary_low  salary_medium
# 0        False        True          False
# 1        False       False           True
# 2        False       False           True
# 3        False        True          False
# 4        False        True          False

# %%
X = final.drop(['left'], axis = 'columns')
Y = df.left
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2)

# %%
model  = LogisticRegression()
model.fit(
